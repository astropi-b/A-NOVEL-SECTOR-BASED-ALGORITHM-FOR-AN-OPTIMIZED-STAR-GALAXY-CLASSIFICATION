# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Dense, Flatten, concatenate, ReLU, AveragePooling2D


# Function to load data and labels
def load_data_and_labels(sector_number):
    
    base_path = f'/kaggle/input/sector{sector_number}'
    galaxy_folder = os.path.join(base_path, 'Augmented_Galaxy_Images', 'Augmented_Galaxy_Images')
    star_folder = os.path.join(base_path, 'Augmented_Star_Images', 'Augmented_Star_Images')
    
    # Adjust file names based on sector
    if sector_number == 16:
        galaxy_csv = os.path.join(base_path, f'galaxys_s{sector_number}.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}.csv')
    elif sector_number == 10:
        galaxy_csv = os.path.join(base_path, f'galaxys_s{sector_number}_200.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}_200.csv')
    elif sector_number == 7:
        galaxy_csv = os.path.join(base_path, f'galaxy_s{sector_number}.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}.csv')

    # Load metadata from CSV files to ensure correct labeling
    galaxy_metadata = pd.read_csv(galaxy_csv, skiprows=1)
    star_metadata = pd.read_csv(star_csv, skiprows=1)

    images = []
    labels = []  # 0 for star, 1 for galaxy

    def extract_objid(filename):
        return filename.split('_')[-1].split('.')[0]

    for file in os.listdir(galaxy_folder):
        if file.endswith('.npy'):
            objid = extract_objid(file)
            if any(galaxy_metadata['objid'].astype(str) == objid):
                img = np.load(os.path.join(galaxy_folder, file))
                images.append(img)
                labels.append(1)

    for file in os.listdir(star_folder):
        if file.endswith('.npy'):
            objid = extract_objid(file)
            if any(star_metadata['objid'].astype(str) == objid):
                img = np.load(os.path.join(star_folder, file))
                images.append(img)
                labels.append(0)

    return np.array(images), np.array(labels)

# Load data from training sectors (7 and 10)
images7, labels7 = load_data_and_labels(7)
images10, labels10 = load_data_and_labels(10)

# Combine the data from the two training sectors
X_train = np.concatenate((images7, images10))
y_train = np.concatenate((labels7, labels10))

# Split training data for validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the CNN model
inp_layer = tf.keras.Input(shape=X_train.shape[1:])

# Initial Convolutional Layer
mod = Conv2D(filters=64, kernel_size=(5, 5), padding='same')(inp_layer)
mod = ReLU()(mod)

# mod = AveragePooling2D(pool_size=(2, 2), strides=2)(mod)

c1 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c1 = ReLU()(c1)
c2 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c2 = ReLU()(c2)
c3 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c3 = ReLU()(c3)
c4 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(c1)
c4 = ReLU()(c4)
c5 = Conv2D(filters=64, kernel_size=(3,3), padding='same')(c1)
c5 = ReLU()(c5)
c6 = Conv2D(filters=64, kernel_size=(5,5), padding='same')(c2)
c6 = ReLU()(c6)
p1 = AveragePooling2D(pool_size=(1, 1))(c3)
mod = concatenate([c4,c5,c6,p1])

c7 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c7 = ReLU()(c7)
c8 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c8 = ReLU()(c8)
c9 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c9 = ReLU()(c9)
c10 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(c7)
c10 = ReLU()(c10)
c11 = Conv2D(filters=92, kernel_size=(3,3), padding='same')(c7)
c11 = ReLU()(c11)
c12 = Conv2D(filters=92, kernel_size=(5,5), padding='same')(c8)
c12 = ReLU()(c12)
p2 = AveragePooling2D(pool_size=(1, 1))(c9)
mod = concatenate([c10,c11,c12,p2])
mod = AveragePooling2D(pool_size=(2, 2))(mod)

c13 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c13 = ReLU()(c13)
c14 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c14 = ReLU()(c14)
c15 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c15 = ReLU()(c15)
c16 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(c13)
c16 = ReLU()(c16)
c17 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c13)
c17 = ReLU()(c17)
c18 = Conv2D(filters=128, kernel_size=(5,5), padding='same')(c14)
c18 = ReLU()(c18)
p3 = AveragePooling2D(pool_size=(1, 1))(c15)
mod = concatenate([c16,c17,c18,p3])

c19 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c19 = ReLU()(c19)
c20 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c20 = ReLU()(c20)
c21 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c21 = ReLU()(c21)
c22 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(c19)
c22 = ReLU()(c22)
c23 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c19)
c23 = ReLU()(c23)
c24 = Conv2D(filters=128, kernel_size=(5,5), padding='same')(c20)
c24 = ReLU()(c24)
p4 = AveragePooling2D(pool_size=(1, 1))(c21)
mod = concatenate([c22,c23,c24,p4])
mod = AveragePooling2D(pool_size=(2, 2))(mod)

c25 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c25 = ReLU()(c25)
c26 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c26 = ReLU()(c26)
c27 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(mod)
c27 = ReLU()(c27)
c28 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c25)
c28 = ReLU()(c28)
p5 = AveragePooling2D(pool_size=(1, 1))(c26)
mod = concatenate([c27,c28,p5])
# Flatten before feeding into Dense layers
mod = Flatten()(mod)

# Dense layers
mod = Dense(1024, activation='relu')(mod)
mod = Dense(1024, activation='relu')(mod)

# Output layer for binary classification
out_layer = Dense(1, activation="sigmoid")(mod)
model = tf.keras.Model(inputs=inp_layer, outputs=out_layer)

# Compile the model for binary classification
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["accuracy"])

# Model Summary
model.summary()
# Ensure labels are in the correct shape for binary_crossentropy
y_train = y_train.flatten()
y_val = y_val.flatten()

# Train the CNN
history = model.fit(
    X_train, y_train,
    epochs=5,
    validation_data=(X_val, y_val),
    batch_size=32
)

# Load test data from sector 16
X_test, y_test = load_data_and_labels(16)
y_test = y_test.flatten()

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy}, Test Loss: {test_loss}")
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 45, 45, 5)]          0         []
#
#  conv2d_204 (Conv2D)         (None, 45, 45, 64)           8064      ['input_9[0][0]']
#
#  re_lu_203 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_204[0][0]']
#
#  conv2d_205 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_203[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_203[0][0]']
#
#  re_lu_204 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_205[0][0]']
#
#  re_lu_205 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_206[0][0]']
#
#  conv2d_207 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_203[0][0]']
#
#  conv2d_208 (Conv2D)         (None, 45, 45, 64)           3136      ['re_lu_204[0][0]']
#
#  conv2d_209 (Conv2D)         (None, 45, 45, 64)           27712     ['re_lu_204[0][0]']
#
#  conv2d_210 (Conv2D)         (None, 45, 45, 64)           76864     ['re_lu_205[0][0]']
#
#  re_lu_206 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_207[0][0]']
#
#  re_lu_207 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_208[0][0]']
#
#  re_lu_208 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_209[0][0]']
#
#  re_lu_209 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_210[0][0]']
#
#  average_pooling2d_49 (Aver  (None, 45, 45, 48)           0         ['re_lu_206[0][0]']
#  agePooling2D)
#
#  concatenate_35 (Concatenat  (None, 45, 45, 240)          0         ['re_lu_207[0][0]',
#  e)                                                                  're_lu_208[0][0]',
#                                                                      're_lu_209[0][0]',
#                                                                      'average_pooling2d_49[0][0]']
#
#  conv2d_211 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_35[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_35[0][0]']
#
#  re_lu_210 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_211[0][0]']
#
#  re_lu_211 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_212[0][0]']
#
#  conv2d_213 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_35[0][0]']
#
#  conv2d_214 (Conv2D)         (None, 45, 45, 92)           5980      ['re_lu_210[0][0]']
#
#  conv2d_215 (Conv2D)         (None, 45, 45, 92)           53084     ['re_lu_210[0][0]']
#
#  conv2d_216 (Conv2D)         (None, 45, 45, 92)           147292    ['re_lu_211[0][0]']
#
#  re_lu_212 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_213[0][0]']
#
#  re_lu_213 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_214[0][0]']
#
#  re_lu_214 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_215[0][0]']
#
#  re_lu_215 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_216[0][0]']
#
#  average_pooling2d_50 (Aver  (None, 45, 45, 64)           0         ['re_lu_212[0][0]']
#  agePooling2D)
#
#  concatenate_36 (Concatenat  (None, 45, 45, 340)          0         ['re_lu_213[0][0]',
#  e)                                                                  're_lu_214[0][0]',
#                                                                      're_lu_215[0][0]',
#                                                                      'average_pooling2d_50[0][0]']
#
#  average_pooling2d_51 (Aver  (None, 22, 22, 340)          0         ['concatenate_36[0][0]']
#  agePooling2D)
#
#  conv2d_217 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_51[0][0]']
#
#  conv2d_218 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_51[0][0]']
#
#  re_lu_216 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_217[0][0]']
#
#  re_lu_217 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_218[0][0]']
#
#  conv2d_219 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_51[0][0]']
#
#  conv2d_220 (Conv2D)         (None, 22, 22, 128)          11904     ['re_lu_216[0][0]']
#
#  conv2d_221 (Conv2D)         (None, 22, 22, 128)          106112    ['re_lu_216[0][0]']
#
#  conv2d_222 (Conv2D)         (None, 22, 22, 128)          294528    ['re_lu_217[0][0]']
#
#  re_lu_218 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_219[0][0]']
#
#  re_lu_219 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_220[0][0]']
#
#  re_lu_220 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_221[0][0]']
#
#  re_lu_221 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_222[0][0]']
#
#  average_pooling2d_52 (Aver  (None, 22, 22, 92)           0         ['re_lu_218[0][0]']
#  agePooling2D)
#
#  concatenate_37 (Concatenat  (None, 22, 22, 476)          0         ['re_lu_219[0][0]',
#  e)                                                                  're_lu_220[0][0]',
#                                                                      're_lu_221[0][0]',
#                                                                      'average_pooling2d_52[0][0]']
#
#  conv2d_223 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_37[0][0]']
#
#  conv2d_224 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_37[0][0]']
#
#  re_lu_222 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_223[0][0]']
#
#  re_lu_223 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_224[0][0]']
#
#  conv2d_225 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_37[0][0]']
#
#  conv2d_226 (Conv2D)         (None, 22, 22, 128)          11904     ['re_lu_222[0][0]']
#
#  conv2d_227 (Conv2D)         (None, 22, 22, 128)          106112    ['re_lu_222[0][0]']
#
#  conv2d_228 (Conv2D)         (None, 22, 22, 128)          294528    ['re_lu_223[0][0]']
#
#  re_lu_224 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_225[0][0]']
#
#  re_lu_225 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_226[0][0]']
#
#  re_lu_226 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_227[0][0]']
#
#  re_lu_227 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_228[0][0]']
#
#  average_pooling2d_53 (Aver  (None, 22, 22, 92)           0         ['re_lu_224[0][0]']
#  agePooling2D)
#
#  concatenate_38 (Concatenat  (None, 22, 22, 476)          0         ['re_lu_225[0][0]',
#  e)                                                                  're_lu_226[0][0]',
#                                                                      're_lu_227[0][0]',
#                                                                      'average_pooling2d_53[0][0]']
#
#  average_pooling2d_54 (Aver  (None, 11, 11, 476)          0         ['concatenate_38[0][0]']
#  agePooling2D)
#
#  conv2d_229 (Conv2D)         (None, 11, 11, 92)           43884     ['average_pooling2d_54[0][0]']
#
#  re_lu_228 (ReLU)            (None, 11, 11, 92)           0         ['conv2d_229[0][0]']
#
#  conv2d_230 (Conv2D)         (None, 11, 11, 92)           43884     ['average_pooling2d_54[0][0]']
#
#  conv2d_231 (Conv2D)         (None, 11, 11, 128)          61056     ['average_pooling2d_54[0][0]']
#
#  conv2d_232 (Conv2D)         (None, 11, 11, 128)          106112    ['re_lu_228[0][0]']
#
#  re_lu_229 (ReLU)            (None, 11, 11, 92)           0         ['conv2d_230[0][0]']
#
#  re_lu_230 (ReLU)            (None, 11, 11, 128)          0         ['conv2d_231[0][0]']
#
#  re_lu_231 (ReLU)            (None, 11, 11, 128)          0         ['conv2d_232[0][0]']
#
#  average_pooling2d_55 (Aver  (None, 11, 11, 92)           0         ['re_lu_229[0][0]']
#  agePooling2D)
#
#  concatenate_39 (Concatenat  (None, 11, 11, 348)          0         ['re_lu_230[0][0]',
#  e)                                                                  're_lu_231[0][0]',
#                                                                      'average_pooling2d_55[0][0]']
#
#  flatten_7 (Flatten)         (None, 42108)                0         ['concatenate_39[0][0]']
#
#  dense_21 (Dense)            (None, 1024)                 4311961   ['flatten_7[0][0]']
#                                                           6
#
#  dense_22 (Dense)            (None, 1024)                 1049600   ['dense_21[0][0]']
#
#  dense_23 (Dense)            (None, 1)                    1025      ['dense_22[0][0]']
#
# ==================================================================================================
# Total params: 45853797 (174.92 MB)
# Trainable params: 45853797 (174.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/5
# 500/500 [==============================] - 54s 89ms/step - loss: 0.6947 - accuracy: 0.5039 - val_loss: 0.6932 - val_accuracy: 0.5002
# Epoch 2/5
# 500/500 [==============================] - 42s 83ms/step - loss: 0.6934 - accuracy: 0.4974 - val_loss: 0.6932 - val_accuracy: 0.5002
# Epoch 3/5
# 500/500 [==============================] - 42s 83ms/step - loss: 0.6932 - accuracy: 0.4932 - val_loss: 0.6932 - val_accuracy: 0.4997
# Epoch 4/5
# 500/500 [==============================] - 41s 83ms/step - loss: 0.6932 - accuracy: 0.4937 - val_loss: 0.6931 - val_accuracy: 0.4997
# Epoch 5/5
# 500/500 [==============================] - 42s 83ms/step - loss: 0.6932 - accuracy: 0.4943 - val_loss: 0.6932 - val_accuracy: 0.4997
# 313/313 [==============================] - 8s 25ms/step - loss: 0.6931 - accuracy: 0.5000
# Test Accuracy: 0.5, Test Loss: 0.6931499242782593

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predictions on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
report = classification_report(y_test, y_pred, target_names=['Star', 'Galaxy'])
print(report)
print(f"Test Accuracy: {test_accuracy}, Test Loss: {test_loss}")
# Out:
# 313/313 [==============================] - 8s 24ms/step
#               precision    recall  f1-score   support
#
#         Star       0.00      0.00      0.00      5000
#       Galaxy       0.50      1.00      0.67      5000
#
#     accuracy                           0.50     10000
#    macro avg       0.25      0.50      0.33     10000
# weighted avg       0.25      0.50      0.33     10000
#
# Test Accuracy: 0.5, Test Loss: 0.6931499242782593
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Training = 16,10 Test = 7

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Dense, Flatten, concatenate, ReLU, AveragePooling2D


# Function to load data and labels
def load_data_and_labels(sector_number):
    
    base_path = f'/kaggle/input/sector{sector_number}'
    galaxy_folder = os.path.join(base_path, 'Augmented_Galaxy_Images', 'Augmented_Galaxy_Images')
    star_folder = os.path.join(base_path, 'Augmented_Star_Images', 'Augmented_Star_Images')
    
    # Adjust file names based on sector
    if sector_number == 16:
        galaxy_csv = os.path.join(base_path, f'galaxys_s{sector_number}.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}.csv')
    elif sector_number == 10:
        galaxy_csv = os.path.join(base_path, f'galaxys_s{sector_number}_200.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}_200.csv')
    elif sector_number == 7:
        galaxy_csv = os.path.join(base_path, f'galaxy_s{sector_number}.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}.csv')

    # Load metadata from CSV files to ensure correct labeling
    galaxy_metadata = pd.read_csv(galaxy_csv, skiprows=1)
    star_metadata = pd.read_csv(star_csv, skiprows=1)

    images = []
    labels = []  # 0 for star, 1 for galaxy

    def extract_objid(filename):
        return filename.split('_')[-1].split('.')[0]

    for file in os.listdir(galaxy_folder):
        if file.endswith('.npy'):
            objid = extract_objid(file)
            if any(galaxy_metadata['objid'].astype(str) == objid):
                img = np.load(os.path.join(galaxy_folder, file))
                images.append(img)
                labels.append(1)

    for file in os.listdir(star_folder):
        if file.endswith('.npy'):
            objid = extract_objid(file)
            if any(star_metadata['objid'].astype(str) == objid):
                img = np.load(os.path.join(star_folder, file))
                images.append(img)
                labels.append(0)

    return np.array(images), np.array(labels)

# Load data from training sectors (7 and 10)
images16, labels16 = load_data_and_labels(16)
images10, labels10 = load_data_and_labels(10)

# Combine the data from the two training sectors
X_train = np.concatenate((images7, images10))
y_train = np.concatenate((labels7, labels10))

# Split training data for validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the CNN model
inp_layer = tf.keras.Input(shape=X_train.shape[1:])

# Initial Convolutional Layer
mod = Conv2D(filters=64, kernel_size=(5, 5), padding='same')(inp_layer)
mod = ReLU()(mod)

# mod = AveragePooling2D(pool_size=(2, 2), strides=2)(mod)

c1 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c1 = ReLU()(c1)
c2 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c2 = ReLU()(c2)
c3 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c3 = ReLU()(c3)
c4 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(c1)
c4 = ReLU()(c4)
c5 = Conv2D(filters=64, kernel_size=(3,3), padding='same')(c1)
c5 = ReLU()(c5)
c6 = Conv2D(filters=64, kernel_size=(5,5), padding='same')(c2)
c6 = ReLU()(c6)
p1 = AveragePooling2D(pool_size=(1, 1))(c3)
mod = concatenate([c4,c5,c6,p1])

c7 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c7 = ReLU()(c7)
c8 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c8 = ReLU()(c8)
c9 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c9 = ReLU()(c9)
c10 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(c7)
c10 = ReLU()(c10)
c11 = Conv2D(filters=92, kernel_size=(3,3), padding='same')(c7)
c11 = ReLU()(c11)
c12 = Conv2D(filters=92, kernel_size=(5,5), padding='same')(c8)
c12 = ReLU()(c12)
p2 = AveragePooling2D(pool_size=(1, 1))(c9)
mod = concatenate([c10,c11,c12,p2])
mod = AveragePooling2D(pool_size=(2, 2))(mod)

c13 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c13 = ReLU()(c13)
c14 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c14 = ReLU()(c14)
c15 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c15 = ReLU()(c15)
c16 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(c13)
c16 = ReLU()(c16)
c17 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c13)
c17 = ReLU()(c17)
c18 = Conv2D(filters=128, kernel_size=(5,5), padding='same')(c14)
c18 = ReLU()(c18)
p3 = AveragePooling2D(pool_size=(1, 1))(c15)
mod = concatenate([c16,c17,c18,p3])

c19 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c19 = ReLU()(c19)
c20 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c20 = ReLU()(c20)
c21 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c21 = ReLU()(c21)
c22 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(c19)
c22 = ReLU()(c22)
c23 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c19)
c23 = ReLU()(c23)
c24 = Conv2D(filters=128, kernel_size=(5,5), padding='same')(c20)
c24 = ReLU()(c24)
p4 = AveragePooling2D(pool_size=(1, 1))(c21)
mod = concatenate([c22,c23,c24,p4])
mod = AveragePooling2D(pool_size=(2, 2))(mod)

c25 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c25 = ReLU()(c25)
c26 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c26 = ReLU()(c26)
c27 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(mod)
c27 = ReLU()(c27)
c28 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c25)
c28 = ReLU()(c28)
p5 = AveragePooling2D(pool_size=(1, 1))(c26)
mod = concatenate([c27,c28,p5])
# Flatten before feeding into Dense layers
mod = Flatten()(mod)

# Dense layers
mod = Dense(1024, activation='relu')(mod)
mod = Dense(1024, activation='relu')(mod)

# Output layer for binary classification
out_layer = Dense(1, activation="sigmoid")(mod)
model = tf.keras.Model(inputs=inp_layer, outputs=out_layer)

# Compile the model for binary classification
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["accuracy"])

# Model Summary
model.summary()
# Ensure labels are in the correct shape for binary_crossentropy
y_train = y_train.flatten()
y_val = y_val.flatten()

# Train the CNN
history = model.fit(
    X_train, y_train,
    epochs=5,
    validation_data=(X_val, y_val),
    batch_size=32
)

# Load test data from sector 16
X_test, y_test = load_data_and_labels(7)
y_test = y_test.flatten()

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy}, Test Loss: {test_loss}")
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 45, 45, 5)]          0         []
#
#  conv2d_175 (Conv2D)         (None, 45, 45, 64)           8064      ['input_8[0][0]']
#
#  re_lu_174 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_175[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_174[0][0]']
#
#  conv2d_177 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_174[0][0]']
#
#  re_lu_175 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_176[0][0]']
#
#  re_lu_176 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_177[0][0]']
#
#  conv2d_178 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_174[0][0]']
#
#  conv2d_179 (Conv2D)         (None, 45, 45, 64)           3136      ['re_lu_175[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 45, 45, 64)           27712     ['re_lu_175[0][0]']
#
#  conv2d_181 (Conv2D)         (None, 45, 45, 64)           76864     ['re_lu_176[0][0]']
#
#  re_lu_177 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_178[0][0]']
#
#  re_lu_178 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_179[0][0]']
#
#  re_lu_179 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_180[0][0]']
#
#  re_lu_180 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_181[0][0]']
#
#  average_pooling2d_42 (Aver  (None, 45, 45, 48)           0         ['re_lu_177[0][0]']
#  agePooling2D)
#
#  concatenate_30 (Concatenat  (None, 45, 45, 240)          0         ['re_lu_178[0][0]',
#  e)                                                                  're_lu_179[0][0]',
#                                                                      're_lu_180[0][0]',
#                                                                      'average_pooling2d_42[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_30[0][0]']
#
#  conv2d_183 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_30[0][0]']
#
#  re_lu_181 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_182[0][0]']
#
#  re_lu_182 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_183[0][0]']
#
#  conv2d_184 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_30[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 45, 45, 92)           5980      ['re_lu_181[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 45, 45, 92)           53084     ['re_lu_181[0][0]']
#
#  conv2d_187 (Conv2D)         (None, 45, 45, 92)           147292    ['re_lu_182[0][0]']
#
#  re_lu_183 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_184[0][0]']
#
#  re_lu_184 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_185[0][0]']
#
#  re_lu_185 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_186[0][0]']
#
#  re_lu_186 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_187[0][0]']
#
#  average_pooling2d_43 (Aver  (None, 45, 45, 64)           0         ['re_lu_183[0][0]']
#  agePooling2D)
#
#  concatenate_31 (Concatenat  (None, 45, 45, 340)          0         ['re_lu_184[0][0]',
#  e)                                                                  're_lu_185[0][0]',
#                                                                      're_lu_186[0][0]',
#                                                                      'average_pooling2d_43[0][0]']
#
#  average_pooling2d_44 (Aver  (None, 22, 22, 340)          0         ['concatenate_31[0][0]']
#  agePooling2D)
#
#  conv2d_188 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_44[0][0]']
#
#  conv2d_189 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_44[0][0]']
#
#  re_lu_187 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_188[0][0]']
#
#  re_lu_188 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_189[0][0]']
#
#  conv2d_190 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_44[0][0]']
#
#  conv2d_191 (Conv2D)         (None, 22, 22, 128)          11904     ['re_lu_187[0][0]']
#
#  conv2d_192 (Conv2D)         (None, 22, 22, 128)          106112    ['re_lu_187[0][0]']
#
#  conv2d_193 (Conv2D)         (None, 22, 22, 128)          294528    ['re_lu_188[0][0]']
#
#  re_lu_189 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_190[0][0]']
#
#  re_lu_190 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_191[0][0]']
#
#  re_lu_191 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_192[0][0]']
#
#  re_lu_192 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_193[0][0]']
#
#  average_pooling2d_45 (Aver  (None, 22, 22, 92)           0         ['re_lu_189[0][0]']
#  agePooling2D)
#
#  concatenate_32 (Concatenat  (None, 22, 22, 476)          0         ['re_lu_190[0][0]',
#  e)                                                                  're_lu_191[0][0]',
#                                                                      're_lu_192[0][0]',
#                                                                      'average_pooling2d_45[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_32[0][0]']
#
#  conv2d_195 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_32[0][0]']
#
#  re_lu_193 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_194[0][0]']
#
#  re_lu_194 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_195[0][0]']
#
#  conv2d_196 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_32[0][0]']
#
#  conv2d_197 (Conv2D)         (None, 22, 22, 128)          11904     ['re_lu_193[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 22, 22, 128)          106112    ['re_lu_193[0][0]']
#
#  conv2d_199 (Conv2D)         (None, 22, 22, 128)          294528    ['re_lu_194[0][0]']
#
#  re_lu_195 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_196[0][0]']
#
#  re_lu_196 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_197[0][0]']
#
#  re_lu_197 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_198[0][0]']
#
#  re_lu_198 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_199[0][0]']
#
#  average_pooling2d_46 (Aver  (None, 22, 22, 92)           0         ['re_lu_195[0][0]']
#  agePooling2D)
#
#  concatenate_33 (Concatenat  (None, 22, 22, 476)          0         ['re_lu_196[0][0]',
#  e)                                                                  're_lu_197[0][0]',
#                                                                      're_lu_198[0][0]',
#                                                                      'average_pooling2d_46[0][0]']
#
#  average_pooling2d_47 (Aver  (None, 11, 11, 476)          0         ['concatenate_33[0][0]']
#  agePooling2D)
#
#  conv2d_200 (Conv2D)         (None, 11, 11, 92)           43884     ['average_pooling2d_47[0][0]']
#
#  re_lu_199 (ReLU)            (None, 11, 11, 92)           0         ['conv2d_200[0][0]']
#
#  conv2d_201 (Conv2D)         (None, 11, 11, 92)           43884     ['average_pooling2d_47[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 11, 11, 128)          61056     ['average_pooling2d_47[0][0]']
#
#  conv2d_203 (Conv2D)         (None, 11, 11, 128)          106112    ['re_lu_199[0][0]']
#
#  re_lu_200 (ReLU)            (None, 11, 11, 92)           0         ['conv2d_201[0][0]']
#
#  re_lu_201 (ReLU)            (None, 11, 11, 128)          0         ['conv2d_202[0][0]']
#
#  re_lu_202 (ReLU)            (None, 11, 11, 128)          0         ['conv2d_203[0][0]']
#
#  average_pooling2d_48 (Aver  (None, 11, 11, 92)           0         ['re_lu_200[0][0]']
#  agePooling2D)
#
#  concatenate_34 (Concatenat  (None, 11, 11, 348)          0         ['re_lu_201[0][0]',
#  e)                                                                  're_lu_202[0][0]',
#                                                                      'average_pooling2d_48[0][0]']
#
#  flatten_6 (Flatten)         (None, 42108)                0         ['concatenate_34[0][0]']
#
#  dense_18 (Dense)            (None, 1024)                 4311961   ['flatten_6[0][0]']
#                                                           6
#
#  dense_19 (Dense)            (None, 1024)                 1049600   ['dense_18[0][0]']
#
#  dense_20 (Dense)            (None, 1)                    1025      ['dense_19[0][0]']
#
# ==================================================================================================
# Total params: 45853797 (174.92 MB)
# Trainable params: 45853797 (174.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/5
# 500/500 [==============================] - 55s 89ms/step - loss: 0.6458 - accuracy: 0.5935 - val_loss: 0.3942 - val_accuracy: 0.8593
# Epoch 2/5
# 500/500 [==============================] - 43s 85ms/step - loss: 0.3154 - accuracy: 0.8759 - val_loss: 0.2854 - val_accuracy: 0.8798
# Epoch 3/5
# 500/500 [==============================] - 43s 87ms/step - loss: 0.2331 - accuracy: 0.9119 - val_loss: 0.2443 - val_accuracy: 0.9143
# Epoch 4/5
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1959 - accuracy: 0.9277 - val_loss: 0.1950 - val_accuracy: 0.9340
# Epoch 5/5
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1745 - accuracy: 0.9362 - val_loss: 0.1556 - val_accuracy: 0.9467
# 313/313 [==============================] - 8s 25ms/step - loss: 0.1389 - accuracy: 0.9516
# Test Accuracy: 0.9516000151634216, Test Loss: 0.1389024555683136

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predictions on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
report = classification_report(y_test, y_pred, target_names=['Star', 'Galaxy'])
print(report)
print(f"Test Accuracy: {test_accuracy}, Test Loss: {test_loss}")
# Out:
# 313/313 [==============================] - 8s 25ms/step
#               precision    recall  f1-score   support
#
#         Star       0.93      0.97      0.95      5000
#       Galaxy       0.97      0.93      0.95      5000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# Test Accuracy: 0.9516000151634216, Test Loss: 0.1389024555683136

# %% [markdown]
# ### Training = 16,7 Test = 10

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Dense, Flatten, concatenate, ReLU, AveragePooling2D


# Function to load data and labels
def load_data_and_labels(sector_number):
    
    base_path = f'/kaggle/input/sector{sector_number}'
    galaxy_folder = os.path.join(base_path, 'Augmented_Galaxy_Images', 'Augmented_Galaxy_Images')
    star_folder = os.path.join(base_path, 'Augmented_Star_Images', 'Augmented_Star_Images')
    
    # Adjust file names based on sector
    if sector_number == 16:
        galaxy_csv = os.path.join(base_path, f'galaxys_s{sector_number}.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}.csv')
    elif sector_number == 10:
        galaxy_csv = os.path.join(base_path, f'galaxys_s{sector_number}_200.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}_200.csv')
    elif sector_number == 7:
        galaxy_csv = os.path.join(base_path, f'galaxy_s{sector_number}.csv')
        star_csv = os.path.join(base_path, f'stars_s{sector_number}.csv')

    # Load metadata from CSV files to ensure correct labeling
    galaxy_metadata = pd.read_csv(galaxy_csv, skiprows=1)
    star_metadata = pd.read_csv(star_csv, skiprows=1)

    images = []
    labels = []  # 0 for star, 1 for galaxy

    def extract_objid(filename):
        return filename.split('_')[-1].split('.')[0]

    for file in os.listdir(galaxy_folder):
        if file.endswith('.npy'):
            objid = extract_objid(file)
            if any(galaxy_metadata['objid'].astype(str) == objid):
                img = np.load(os.path.join(galaxy_folder, file))
                images.append(img)
                labels.append(1)

    for file in os.listdir(star_folder):
        if file.endswith('.npy'):
            objid = extract_objid(file)
            if any(star_metadata['objid'].astype(str) == objid):
                img = np.load(os.path.join(star_folder, file))
                images.append(img)
                labels.append(0)

    return np.array(images), np.array(labels)

# Load data from training sectors (7 and 10)
images16, labels16 = load_data_and_labels(16)
images7, labels7 = load_data_and_labels(7)

# Combine the data from the two training sectors
X_train = np.concatenate((images7, images10))
y_train = np.concatenate((labels7, labels10))

# Split training data for validation
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the CNN model
inp_layer = tf.keras.Input(shape=X_train.shape[1:])

# Initial Convolutional Layer
mod = Conv2D(filters=64, kernel_size=(5, 5), padding='same')(inp_layer)
mod = ReLU()(mod)

# mod = AveragePooling2D(pool_size=(2, 2), strides=2)(mod)

c1 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c1 = ReLU()(c1)
c2 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c2 = ReLU()(c2)
c3 = Conv2D(filters=48, kernel_size=(1,1), padding='same')(mod)
c3 = ReLU()(c3)
c4 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(c1)
c4 = ReLU()(c4)
c5 = Conv2D(filters=64, kernel_size=(3,3), padding='same')(c1)
c5 = ReLU()(c5)
c6 = Conv2D(filters=64, kernel_size=(5,5), padding='same')(c2)
c6 = ReLU()(c6)
p1 = AveragePooling2D(pool_size=(1, 1))(c3)
mod = concatenate([c4,c5,c6,p1])

c7 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c7 = ReLU()(c7)
c8 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c8 = ReLU()(c8)
c9 = Conv2D(filters=64, kernel_size=(1,1), padding='same')(mod)
c9 = ReLU()(c9)
c10 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(c7)
c10 = ReLU()(c10)
c11 = Conv2D(filters=92, kernel_size=(3,3), padding='same')(c7)
c11 = ReLU()(c11)
c12 = Conv2D(filters=92, kernel_size=(5,5), padding='same')(c8)
c12 = ReLU()(c12)
p2 = AveragePooling2D(pool_size=(1, 1))(c9)
mod = concatenate([c10,c11,c12,p2])
mod = AveragePooling2D(pool_size=(2, 2))(mod)

c13 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c13 = ReLU()(c13)
c14 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c14 = ReLU()(c14)
c15 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c15 = ReLU()(c15)
c16 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(c13)
c16 = ReLU()(c16)
c17 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c13)
c17 = ReLU()(c17)
c18 = Conv2D(filters=128, kernel_size=(5,5), padding='same')(c14)
c18 = ReLU()(c18)
p3 = AveragePooling2D(pool_size=(1, 1))(c15)
mod = concatenate([c16,c17,c18,p3])

c19 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c19 = ReLU()(c19)
c20 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c20 = ReLU()(c20)
c21 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c21 = ReLU()(c21)
c22 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(c19)
c22 = ReLU()(c22)
c23 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c19)
c23 = ReLU()(c23)
c24 = Conv2D(filters=128, kernel_size=(5,5), padding='same')(c20)
c24 = ReLU()(c24)
p4 = AveragePooling2D(pool_size=(1, 1))(c21)
mod = concatenate([c22,c23,c24,p4])
mod = AveragePooling2D(pool_size=(2, 2))(mod)

c25 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c25 = ReLU()(c25)
c26 = Conv2D(filters=92, kernel_size=(1,1), padding='same')(mod)
c26 = ReLU()(c26)
c27 = Conv2D(filters=128, kernel_size=(1,1), padding='same')(mod)
c27 = ReLU()(c27)
c28 = Conv2D(filters=128, kernel_size=(3,3), padding='same')(c25)
c28 = ReLU()(c28)
p5 = AveragePooling2D(pool_size=(1, 1))(c26)
mod = concatenate([c27,c28,p5])
# Flatten before feeding into Dense layers
mod = Flatten()(mod)

# Dense layers
mod = Dense(1024, activation='relu')(mod)
mod = Dense(1024, activation='relu')(mod)

# Output layer for binary classification
out_layer = Dense(1, activation="sigmoid")(mod)
model = tf.keras.Model(inputs=inp_layer, outputs=out_layer)

# Compile the model for binary classification
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=["accuracy"])

# Model Summary
model.summary()
# Ensure labels are in the correct shape for binary_crossentropy
y_train = y_train.flatten()
y_val = y_val.flatten()

# Train the CNN
history = model.fit(
    X_train, y_train,
    epochs=5,
    validation_data=(X_val, y_val),
    batch_size=32
)

# Load test data from sector 16
X_test, y_test = load_data_and_labels(10)
y_test = y_test.flatten()

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy}, Test Loss: {test_loss}")
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 45, 45, 5)]          0         []
#
#  conv2d_117 (Conv2D)         (None, 45, 45, 64)           8064      ['input_6[0][0]']
#
#  re_lu_116 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_117[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_116[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_116[0][0]']
#
#  re_lu_117 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_118[0][0]']
#
#  re_lu_118 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_119[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 45, 45, 48)           3120      ['re_lu_116[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 45, 45, 64)           3136      ['re_lu_117[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 45, 45, 64)           27712     ['re_lu_117[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 45, 45, 64)           76864     ['re_lu_118[0][0]']
#
#  re_lu_119 (ReLU)            (None, 45, 45, 48)           0         ['conv2d_120[0][0]']
#
#  re_lu_120 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_121[0][0]']
#
#  re_lu_121 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_122[0][0]']
#
#  re_lu_122 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_123[0][0]']
#
#  average_pooling2d_28 (Aver  (None, 45, 45, 48)           0         ['re_lu_119[0][0]']
#  agePooling2D)
#
#  concatenate_20 (Concatenat  (None, 45, 45, 240)          0         ['re_lu_120[0][0]',
#  e)                                                                  're_lu_121[0][0]',
#                                                                      're_lu_122[0][0]',
#                                                                      'average_pooling2d_28[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_20[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_20[0][0]']
#
#  re_lu_123 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_124[0][0]']
#
#  re_lu_124 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_125[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 45, 45, 64)           15424     ['concatenate_20[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 45, 45, 92)           5980      ['re_lu_123[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 45, 45, 92)           53084     ['re_lu_123[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 45, 45, 92)           147292    ['re_lu_124[0][0]']
#
#  re_lu_125 (ReLU)            (None, 45, 45, 64)           0         ['conv2d_126[0][0]']
#
#  re_lu_126 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_127[0][0]']
#
#  re_lu_127 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_128[0][0]']
#
#  re_lu_128 (ReLU)            (None, 45, 45, 92)           0         ['conv2d_129[0][0]']
#
#  average_pooling2d_29 (Aver  (None, 45, 45, 64)           0         ['re_lu_125[0][0]']
#  agePooling2D)
#
#  concatenate_21 (Concatenat  (None, 45, 45, 340)          0         ['re_lu_126[0][0]',
#  e)                                                                  're_lu_127[0][0]',
#                                                                      're_lu_128[0][0]',
#                                                                      'average_pooling2d_29[0][0]']
#
#  average_pooling2d_30 (Aver  (None, 22, 22, 340)          0         ['concatenate_21[0][0]']
#  agePooling2D)
#
#  conv2d_130 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_30[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_30[0][0]']
#
#  re_lu_129 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_130[0][0]']
#
#  re_lu_130 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 22, 22, 92)           31372     ['average_pooling2d_30[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 22, 22, 128)          11904     ['re_lu_129[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 22, 22, 128)          106112    ['re_lu_129[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 22, 22, 128)          294528    ['re_lu_130[0][0]']
#
#  re_lu_131 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_132[0][0]']
#
#  re_lu_132 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_133[0][0]']
#
#  re_lu_133 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_134[0][0]']
#
#  re_lu_134 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_135[0][0]']
#
#  average_pooling2d_31 (Aver  (None, 22, 22, 92)           0         ['re_lu_131[0][0]']
#  agePooling2D)
#
#  concatenate_22 (Concatenat  (None, 22, 22, 476)          0         ['re_lu_132[0][0]',
#  e)                                                                  're_lu_133[0][0]',
#                                                                      're_lu_134[0][0]',
#                                                                      'average_pooling2d_31[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_22[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_22[0][0]']
#
#  re_lu_135 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_136[0][0]']
#
#  re_lu_136 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_137[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 22, 22, 92)           43884     ['concatenate_22[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 22, 22, 128)          11904     ['re_lu_135[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 22, 22, 128)          106112    ['re_lu_135[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 22, 22, 128)          294528    ['re_lu_136[0][0]']
#
#  re_lu_137 (ReLU)            (None, 22, 22, 92)           0         ['conv2d_138[0][0]']
#
#  re_lu_138 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_139[0][0]']
#
#  re_lu_139 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_140[0][0]']
#
#  re_lu_140 (ReLU)            (None, 22, 22, 128)          0         ['conv2d_141[0][0]']
#
#  average_pooling2d_32 (Aver  (None, 22, 22, 92)           0         ['re_lu_137[0][0]']
#  agePooling2D)
#
#  concatenate_23 (Concatenat  (None, 22, 22, 476)          0         ['re_lu_138[0][0]',
#  e)                                                                  're_lu_139[0][0]',
#                                                                      're_lu_140[0][0]',
#                                                                      'average_pooling2d_32[0][0]']
#
#  average_pooling2d_33 (Aver  (None, 11, 11, 476)          0         ['concatenate_23[0][0]']
#  agePooling2D)
#
#  conv2d_142 (Conv2D)         (None, 11, 11, 92)           43884     ['average_pooling2d_33[0][0]']
#
#  re_lu_141 (ReLU)            (None, 11, 11, 92)           0         ['conv2d_142[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 11, 11, 92)           43884     ['average_pooling2d_33[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 11, 11, 128)          61056     ['average_pooling2d_33[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 11, 11, 128)          106112    ['re_lu_141[0][0]']
#
#  re_lu_142 (ReLU)            (None, 11, 11, 92)           0         ['conv2d_143[0][0]']
#
#  re_lu_143 (ReLU)            (None, 11, 11, 128)          0         ['conv2d_144[0][0]']
#
#  re_lu_144 (ReLU)            (None, 11, 11, 128)          0         ['conv2d_145[0][0]']
#
#  average_pooling2d_34 (Aver  (None, 11, 11, 92)           0         ['re_lu_142[0][0]']
#  agePooling2D)
#
#  concatenate_24 (Concatenat  (None, 11, 11, 348)          0         ['re_lu_143[0][0]',
#  e)                                                                  're_lu_144[0][0]',
#                                                                      'average_pooling2d_34[0][0]']
#
#  flatten_4 (Flatten)         (None, 42108)                0         ['concatenate_24[0][0]']
#
#  dense_12 (Dense)            (None, 1024)                 4311961   ['flatten_4[0][0]']
#                                                           6
#
#  dense_13 (Dense)            (None, 1024)                 1049600   ['dense_12[0][0]']
#
#  dense_14 (Dense)            (None, 1)                    1025      ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 45853797 (174.92 MB)
# Trainable params: 45853797 (174.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/5
# 500/500 [==============================] - 55s 90ms/step - loss: 0.4647 - accuracy: 0.7717 - val_loss: 0.3182 - val_accuracy: 0.8800
# Epoch 2/5
# 500/500 [==============================] - 43s 86ms/step - loss: 0.2668 - accuracy: 0.8991 - val_loss: 0.2613 - val_accuracy: 0.8960
# Epoch 3/5
# 500/500 [==============================] - 43s 86ms/step - loss: 0.2082 - accuracy: 0.9212 - val_loss: 0.1919 - val_accuracy: 0.9258
# Epoch 4/5
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1841 - accuracy: 0.9317 - val_loss: 0.1703 - val_accuracy: 0.9360
# Epoch 5/5
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1729 - accuracy: 0.9371 - val_loss: 0.1653 - val_accuracy: 0.9410
# 313/313 [==============================] - 8s 25ms/step - loss: 0.1384 - accuracy: 0.9497
# Test Accuracy: 0.9496999979019165, Test Loss: 0.13840319216251373

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(X_val, y_val)
print("Validation Accuracy: ", val_accuracy)

# Predictions
y_pred = model.predict(X_val)
y_pred_classes = (y_pred > 0.5).astype("int32")

# Confusion Matrix
cm = confusion_matrix(y_val, y_pred_classes)
print("Confusion Matrix:")
print(cm)

# Classification Report (Precision, Recall, F1-score)
print("Classification Report:")
print(classification_report(y_val, y_pred_classes))

# Plotting training history
def plot_training_history(history):
    # Accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_training_history(history)
# Out:
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1653 - accuracy: 0.9410
# Validation Accuracy:  0.9409999847412109
# 125/125 [==============================] - 3s 24ms/step
# Confusion Matrix:
# [[1905   96]
#  [ 140 1859]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      2001
#            1       0.95      0.93      0.94      1999
#
#     accuracy                           0.94      4000
#    macro avg       0.94      0.94      0.94      4000
# weighted avg       0.94      0.94      0.94      4000

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predictions on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
report = classification_report(y_test, y_pred, target_names=['Star', 'Galaxy'])
print(report)
print(f"Test Accuracy: {test_accuracy}, Test Loss: {test_loss}")
# Out:
# 313/313 [==============================] - 8s 25ms/step
#               precision    recall  f1-score   support
#
#         Star       0.95      0.95      0.95      5000
#       Galaxy       0.95      0.95      0.95      5000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# Test Accuracy: 0.9496999979019165, Test Loss: 0.13840319216251373
